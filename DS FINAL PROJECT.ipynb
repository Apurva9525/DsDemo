# %% [markdown]
# Project Name: Predicting Internet Speed Stability
#
# Dataset Link =https://www.kaggle.com/datasets/getanmolgupta01/internet-speed
#
#
#
#
# About Dataset Internet Speed Prediction Dataset
#
# Ping_latency: Time taken for a signal to travel from the source to the destination.
#
# Download_speed: Rate at which data is transferred from the internet to the user's device.
#
# Upload_speed: Rate at which data is transferred from the user's device to the internet.
#
# Packet_loss_rate: Proportion of data packets lost during transmission.
#
# Router_distance: Physical distance between the user's device and the router.
#
# Network_congestion: Level of congestion within the network.
#
# ISP_quality: Quality of service provided by the Internet Service Provider (ISP).
#
# Connection_type_DSL, Connection_type_Cable, Connection_type_Fiber: Binary indicators for the type of internet connection.
#
# Signal_strength: Strength of the wireless signal received by the user's device.
#
# Weather_conditions: Environmental factors that may affect internet performance.
#
#
#
#
#
# Target Feature: Stability_Category

# %%
import pandas as pd

# %%
df=pd.read_csv(r"Internet Speed.csv")

# %%
# Out:
#       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 0        21.854305       42.395374     19.934759          0.999340
# 1        47.782144       49.976388     17.979781          1.493494
# 2        37.939727       86.182002     10.455388          1.125334
# 3        31.939632       37.300417     31.148800          0.166605
# 4        12.020839       87.616720     24.877960          0.371160
# ...            ...             ...           ...               ...
# 4995     45.382879       86.477319     33.242407          1.754077
# 4996     10.372146       90.263339     10.534320          0.093628
# 4997     19.752928       94.937252      4.459498          0.607397
# 4998     41.708542       42.761359     34.782156          0.886640
# 4999     31.879057       25.628338     14.051793          0.344530
#
#       Router_distance  Network_congestion  ISP_quality  Connection_type_DSL  \
# 0            7.569985            1.369483     7.467012             0.000000
# ...

# %%
df.isnull()
# Out:
#       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 0            False           False         False             False
# 1            False           False         False             False
# 2            False           False         False             False
# 3            False           False         False             False
# 4            False           False         False             False
# ...            ...             ...           ...               ...
# 4995         False           False         False             False
# 4996         False           False         False             False
# 4997         False           False         False             False
# 4998         False           False         False             False
# 4999         False           False         False             False
#
#       Router_distance  Network_congestion  ISP_quality  Connection_type_DSL  \
# 0               False               False        False                False
# ...

# %%
df.notnull()
# Out:
#       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 0             True            True          True              True
# 1             True            True          True              True
# 2             True            True          True              True
# 3             True            True          True              True
# 4             True            True          True              True
# ...            ...             ...           ...               ...
# 4995          True            True          True              True
# 4996          True            True          True              True
# 4997          True            True          True              True
# 4998          True            True          True              True
# 4999          True            True          True              True
#
#       Router_distance  Network_congestion  ISP_quality  Connection_type_DSL  \
# 0                True                True         True                 True
# ...

# %%
df.describe()
# Out:
#        Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# count   5000.000000     5000.000000   5000.000000       5000.000000
# mean      27.357440       51.691277     26.066003          1.015369
# std       13.033514       27.133568     13.956951          0.575612
# min        5.000524        5.005019      2.007572          0.000505
# 25%       15.973826       28.478861     13.864032          0.525459
# 50%       27.500388       51.167300     25.817462          1.024899
# 75%       38.664539       74.670302     38.509712          1.502211
# max       49.987295       99.952993     49.990647          1.999850
#
#        Router_distance  Network_congestion  ISP_quality  Connection_type_DSL  \
# count      5000.000000         5000.000000  5000.000000          5000.000000
# mean          5.578994            2.965295     6.504300             1.272947
# std           2.598671            1.138216     2.018279             1.637940
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 0        21.854305       42.395374     19.934759          0.999340
# 1        47.782144       49.976388     17.979781          1.493494
# 2        37.939727       86.182002     10.455388          1.125334
# 3        31.939632       37.300417     31.148800          0.166605
# 4        12.020839       87.616720     24.877960          0.371160
# ...            ...             ...           ...               ...
# 4995     45.382879       86.477319     33.242407          1.754077
# 4996     10.372146       90.263339     10.534320          0.093628
# 4997     19.752928       94.937252      4.459498          0.607397
# 4998     41.708542       42.761359     34.782156          0.886640
# 4999     31.879057       25.628338     14.051793          0.344530
#
#       Router_distance  Network_congestion  ISP_quality  Connection_type_DSL  \
# ...

# %%
df.isna()
# Out:
#       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 0            False           False         False             False
# 1            False           False         False             False
# 2            False           False         False             False
# 3            False           False         False             False
# 4            False           False         False             False
# ...            ...             ...           ...               ...
# 4995         False           False         False             False
# 4996         False           False         False             False
# 4997         False           False         False             False
# 4998         False           False         False             False
# 4999         False           False         False             False
#
#       Router_distance  Network_congestion  ISP_quality  Connection_type_DSL  \
# 0               False               False        False                False
# ...

# %%
df.isnull().sum()
# Out:
# Ping_latency             0
# Download_speed           0
# Upload_speed             0
# Packet_loss_rate         0
# Router_distance          0
# Network_congestion       0
# ISP_quality              0
# Connection_type_DSL      0
# Connection_type_Cable    0
# Connection_type_Fiber    0
# Signal_strength          0
# Weather_conditions       0
# Internet_speed           0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Ping_latency             5000
# Download_speed           5000
# Upload_speed             5000
# Packet_loss_rate         5000
# Router_distance          5000
# Network_congestion       5000
# ISP_quality              5000
# Connection_type_DSL      5000
# Connection_type_Cable    5000
# Connection_type_Fiber    5000
# Signal_strength          5000
# Weather_conditions       5000
# Internet_speed           5000
# dtype: int64

# %%
df.isna().sum()
# Out:
# Ping_latency             0
# Download_speed           0
# Upload_speed             0
# Packet_loss_rate         0
# Router_distance          0
# Network_congestion       0
# ISP_quality              0
# Connection_type_DSL      0
# Connection_type_Cable    0
# Connection_type_Fiber    0
# Signal_strength          0
# Weather_conditions       0
# Internet_speed           0
# dtype: int64

# %%
df.dropna()
# Out:
#       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 0        21.854305       42.395374     19.934759          0.999340
# 1        47.782144       49.976388     17.979781          1.493494
# 2        37.939727       86.182002     10.455388          1.125334
# 3        31.939632       37.300417     31.148800          0.166605
# 4        12.020839       87.616720     24.877960          0.371160
# ...            ...             ...           ...               ...
# 4995     45.382879       86.477319     33.242407          1.754077
# 4996     10.372146       90.263339     10.534320          0.093628
# 4997     19.752928       94.937252      4.459498          0.607397
# 4998     41.708542       42.761359     34.782156          0.886640
# 4999     31.879057       25.628338     14.051793          0.344530
#
#       Router_distance  Network_congestion  ISP_quality  Connection_type_DSL  \
# 0            7.569985            1.369483     7.467012             0.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 5))
sns.boxplot(y=df['Download_speed'], color='skyblue')
plt.title('Download Speed Distribution', fontsize=14)
plt.ylabel('Speed (Mbps)', fontsize=12)
# Out:
# Text(0, 0.5, 'Speed (Mbps)')

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df["Internet_speed"], bins=30, kde=True)
plt.title("Internet Speed Distribution")
plt.xlabel("Internet Speed")
plt.ylabel("Frequency")
plt.show()

# %%
max_speed = df['Internet_speed'].max()  
bins = [0, 500, 1500, 2500, max_speed + 1]  
labels = ["Very Unstable", "Unstable", "Stable", "Very Stable"]

df['Stability_Category'] = pd.cut(df['Internet_speed'], bins=bins, labels=labels)     #cut() : used for the equal binning

# %%
df
# Out:
#       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 0        21.854305       42.395374     19.934759          0.999340
# 1        47.782144       49.976388     17.979781          1.493494
# 2        37.939727       86.182002     10.455388          1.125334
# 3        31.939632       37.300417     31.148800          0.166605
# 4        12.020839       87.616720     24.877960          0.371160
# ...            ...             ...           ...               ...
# 4995     45.382879       86.477319     33.242407          1.754077
# 4996     10.372146       90.263339     10.534320          0.093628
# 4997     19.752928       94.937252      4.459498          0.607397
# 4998     41.708542       42.761359     34.782156          0.886640
# 4999     31.879057       25.628338     14.051793          0.344530
#
#       Router_distance  Network_congestion  ISP_quality  Connection_type_DSL  \
# 0            7.569985            1.369483     7.467012             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Ping_latency             0
# Download_speed           0
# Upload_speed             0
# Packet_loss_rate         0
# Router_distance          0
# Network_congestion       0
# ISP_quality              0
# Connection_type_DSL      0
# Connection_type_Cable    0
# Connection_type_Fiber    0
# Signal_strength          0
# Weather_conditions       0
# Internet_speed           0
# Stability_Category       0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Ping_latency             0
# Download_speed           0
# Upload_speed             0
# Packet_loss_rate         0
# Router_distance          0
# Network_congestion       0
# ISP_quality              0
# Connection_type_DSL      0
# Connection_type_Cable    0
# Connection_type_Fiber    0
# Signal_strength          0
# Weather_conditions       0
# Internet_speed           0
# Stability_Category       0
# dtype: int64

# %%
df['Stability_Category'].replace(["Very Unstable", "Unstable", "Stable", "Very Stable"],[1,2,3,4],inplace=True)
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_12428\836382175.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Stability_Category'].replace(["Very Unstable", "Unstable", "Stable", "Very Stable"],[1,2,3,4],inplace=True)
# ...

# %%
df
# Out:
#       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 0        21.854305       42.395374     19.934759          0.999340
# 1        47.782144       49.976388     17.979781          1.493494
# 2        37.939727       86.182002     10.455388          1.125334
# 3        31.939632       37.300417     31.148800          0.166605
# 4        12.020839       87.616720     24.877960          0.371160
# ...            ...             ...           ...               ...
# 4995     45.382879       86.477319     33.242407          1.754077
# 4996     10.372146       90.263339     10.534320          0.093628
# 4997     19.752928       94.937252      4.459498          0.607397
# 4998     41.708542       42.761359     34.782156          0.886640
# 4999     31.879057       25.628338     14.051793          0.344530
#
#       Router_distance  Network_congestion  ISP_quality  Connection_type_DSL  \
# 0            7.569985            1.369483     7.467012             0.000000
# ...

# %%
x= df[["Ping_latency", "Download_speed", "Upload_speed", "Packet_loss_rate","Network_congestion", "Connection_type_DSL", "Connection_type_Cable", 
        "Connection_type_Fiber", "Signal_strength", "Weather_conditions"]]
y=df["Stability_Category"]

# %%
x
# Out:
#       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 0        21.854305       42.395374     19.934759          0.999340
# 1        47.782144       49.976388     17.979781          1.493494
# 2        37.939727       86.182002     10.455388          1.125334
# 3        31.939632       37.300417     31.148800          0.166605
# 4        12.020839       87.616720     24.877960          0.371160
# ...            ...             ...           ...               ...
# 4995     45.382879       86.477319     33.242407          1.754077
# 4996     10.372146       90.263339     10.534320          0.093628
# 4997     19.752928       94.937252      4.459498          0.607397
# 4998     41.708542       42.761359     34.782156          0.886640
# 4999     31.879057       25.628338     14.051793          0.344530
#
#       Network_congestion  Connection_type_DSL  Connection_type_Cable  \
# 0               1.369483             0.000000               0.000000
# ...

# %%
y
# Out:
# 0       2
# 1       2
# 2       4
# 3       2
# 4       4
#        ..
# 4995    4
# 4996    4
# 4997    4
# 4998    2
# 4999    1
# Name: Stability_Category, Length: 5000, dtype: category
# Categories (4, int64): [1 < 2 < 3 < 4]

# %%
import sklearn as sk
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8)

# %%
x_train
# Out:
#       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 2281     21.283389       10.089773     49.513639          0.720797
# 3917     20.561274       83.772269     37.351722          1.625906
# 1550     47.813150       36.739942     10.653926          0.319571
# 4876     32.042547       10.525937      3.088968          0.277855
# 3726      7.781381       43.362045     49.542355          0.061248
# ...            ...             ...           ...               ...
# 2604      5.006061       35.417211     41.392418          0.037461
# 1475     35.041702       92.842568     10.767826          0.358420
# 607      21.392144       89.629054     43.816978          1.371745
# 456       5.510914       39.834494     14.085846          1.732830
# 3461     12.029296       90.641156     10.761514          1.611472
#
#       Network_congestion  Connection_type_DSL  Connection_type_Cable  \
# 2281            2.582138             0.000000               1.398207
# ...

# %%
x_test
# Out:
#       Ping_latency  Download_speed  Upload_speed  Packet_loss_rate  \
# 3435     22.515371       28.441005     48.076550          0.019462
# 3301     49.873206       29.608339     12.245498          0.375056
# 549      39.754328       17.887839      9.645586          1.617431
# 3773     37.985005       44.084039     40.543617          1.143475
# 1873     42.831636       37.321184     31.972397          1.706081
# ...            ...             ...           ...               ...
# 2780      7.249056       48.272661     34.642929          0.155966
# 3542     11.611487       81.404810      4.528320          0.997015
# 1696      6.161536       67.876730     24.284788          1.366417
# 3884     44.878180       81.991127     14.168297          1.673435
# 4618     18.610984       73.619561     39.326843          1.593985
#
#       Network_congestion  Connection_type_DSL  Connection_type_Cable  \
# 3435            4.861584             4.881321               0.000000
# ...

# %%
y_train
# Out:
# 2281    1
# 3917    3
# 1550    2
# 4876    1
# 3726    2
#        ..
# 2604    2
# 1475    4
# 607     4
# 456     2
# 3461    4
# Name: Stability_Category, Length: 4000, dtype: category
# Categories (4, int64): [1 < 2 < 3 < 4]

# %%
y_test
# Out:
# 3435    1
# 3301    2
# 549     1
# 3773    2
# 1873    2
#        ..
# 2780    2
# 3542    3
# 1696    3
# 3884    3
# 4618    3
# Name: Stability_Category, Length: 1000, dtype: category
# Categories (4, int64): [1 < 2 < 3 < 4]

# %% [markdown]
# Model No.1
#
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\prath\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 2, 4, 3, 2, 4, 1, 1, 1, 2, 4, 1, 1, 4, 1, 1,
#        3, 1, 1, 4, 1, 3, 2, 3, 3, 4, 3, 1, 2, 1, 3, 4, 2, 4, 1, 4, 1, 4,
#        3, 2, 1, 3, 2, 2, 2, 3, 2, 4, 1, 3, 3, 2, 2, 2, 2, 1, 3, 2, 2, 1,
#        3, 1, 4, 2, 4, 4, 2, 2, 2, 1, 3, 3, 2, 2, 2, 2, 1, 1, 4, 1, 2, 1,
#        2, 3, 4, 1, 2, 2, 2, 4, 2, 4, 4, 4, 2, 2, 3, 4, 1, 1, 2, 2, 2, 4,
#        1, 2, 4, 2, 1, 2, 2, 1, 1, 1, 1, 2, 2, 4, 2, 1, 3, 2, 2, 2, 1, 3,
#        4, 1, 3, 2, 3, 1, 2, 3, 2, 3, 2, 2, 2, 2, 3, 3, 2, 2, 2, 4, 1, 2,
#        4, 1, 1, 2, 2, 2, 2, 2, 2, 3, 2, 3, 3, 2, 4, 4, 2, 1, 2, 4, 4, 2,
#        1, 2, 1, 2, 3, 2, 2, 2, 3, 2, 1, 2, 2, 3, 1, 3, 2, 2, 2, 2, 1, 2,
#        1, 2, 3, 1, 1, 2, 2, 1, 1, 2, 3, 1, 2, 4, 2, 2, 2, 4, 1, 3, 1, 2,
#        1, 2, 4, 2, 4, 2, 1, 4, 1, 2, 1, 2, 2, 2, 2, 1, 1, 2, 1, 1, 2, 4,
#        1, 1, 4, 3, 2, 3, 1, 4, 4, 2, 3, 1, 1, 3, 1, 2, 3, 1, 2, 4, 1, 3,
#        1, 3, 2, 1, 1, 4, 1, 2, 1, 2, 4, 1, 4, 2, 4, 4, 1, 4, 3, 3, 2, 2,
# ...

# %%
model.score(x_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_absolute_error 
import sklearn as sk 
sk.metrics.mean_squared_error(y_test,y_pred)
# Out:
# 0.149

# %%
mae = mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 0.149

# %%
import numpy as np

# %%
np.sqrt(mae)
# Out:
# np.float64(0.38600518131237566)

# %%
from sklearn.metrics import accuracy_score 
acc=accuracy_score(y_test,y_pred)*100 
print("Accuracy of Logistic model:",acc,"%")
# Out:
# Accuracy of Logistic model: 85.1 %

# %%
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[286,  20,   0,   0],
#        [ 15, 325,  17,   0],
#        [  0,  25, 142,  43],
#        [  0,   0,  29,  98]])

# %%
cm.ravel()
# Out:
# array([286,  20,   0,   0,  15, 325,  17,   0,   0,  25, 142,  43,   0,
#          0,  29,  98])

# %%
classes, counts = np.unique(y_pred, return_counts=True)
classes
counts
plt.figure(figsize=(6, 4))
sns.barplot(x=classes, y=counts, palette=['blue', 'green', 'orange', 'red'])  # Corrected color usage
plt.xlabel("Predicted Class")
plt.ylabel("Count")
plt.title("Logistic Regression Prediction Distribution")
plt.show()
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_12428\799960678.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=classes, y=counts, palette=['blue', 'green', 'orange', 'red'])  # Corrected color usage

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 1", "Class 2", "Class 3", "Class 4"], yticklabels=["Class 1", "Class 2", "Class 3", "Class 4"])
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.title("Confusion Matrix for Logistic Regression")
plt.show()

# %%
from sklearn.metrics import precision_score 
pr=precision_score(y_test,y_pred,average='macro')

# %%
pr
# Out:
# 0.8197247753160667

# %%
from sklearn.metrics import recall_score 
re=recall_score(y_test,y_pred,average='macro')

# %%
re
# Out:
# 0.8232121720079107

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_pred, average="macro")

# %%
f1
# Out:
# 0.8203339446822896

# %%
from sklearn.metrics import classification_report 
cr=classification_report(y_test,y_pred)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.95      0.93      0.94       306
#            2       0.88      0.91      0.89       357
#            3       0.76      0.68      0.71       210
#            4       0.70      0.77      0.73       127
#
#     accuracy                           0.85      1000
#    macro avg       0.82      0.82      0.82      1000
# weighted avg       0.85      0.85      0.85      1000

# %% [markdown]
# Model No.2
#
# Gaussian Naive-Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model1=GaussianNB()

# %%
model1
# Out:
# GaussianNB()

# %%
model1.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model1.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 2, 3, 4, 1, 4, 1, 1, 1, 2, 3, 1, 1, 4, 1, 1,
#        3, 2, 1, 3, 1, 3, 2, 2, 3, 4, 2, 1, 1, 1, 3, 4, 2, 4, 1, 4, 1, 3,
#        3, 2, 1, 3, 2, 2, 3, 3, 3, 4, 1, 3, 3, 2, 2, 2, 2, 1, 3, 2, 2, 1,
#        3, 1, 4, 2, 4, 4, 2, 2, 3, 1, 3, 3, 2, 2, 2, 2, 1, 1, 4, 1, 2, 1,
#        1, 3, 4, 1, 2, 3, 2, 4, 2, 4, 3, 4, 2, 2, 3, 4, 1, 1, 2, 2, 2, 3,
#        1, 2, 3, 2, 1, 3, 2, 1, 1, 1, 1, 2, 2, 4, 1, 1, 3, 2, 2, 2, 1, 3,
#        3, 1, 3, 3, 3, 1, 2, 3, 2, 2, 2, 2, 2, 2, 3, 4, 2, 2, 2, 4, 1, 2,
#        3, 1, 1, 1, 2, 2, 2, 2, 2, 3, 1, 3, 3, 2, 4, 4, 2, 1, 2, 4, 3, 2,
#        1, 2, 1, 2, 3, 2, 2, 2, 3, 2, 2, 2, 2, 3, 1, 3, 2, 2, 2, 2, 1, 2,
#        2, 2, 3, 1, 1, 2, 1, 1, 1, 2, 4, 1, 2, 4, 2, 3, 2, 4, 1, 3, 1, 2,
#        1, 2, 4, 2, 3, 2, 1, 4, 1, 3, 1, 2, 1, 3, 2, 1, 1, 2, 1, 1, 2, 4,
#        1, 1, 4, 3, 2, 3, 1, 4, 4, 2, 3, 1, 1, 3, 1, 2, 3, 1, 2, 4, 1, 4,
#        1, 3, 2, 1, 1, 4, 1, 2, 1, 2, 4, 1, 4, 2, 4, 4, 1, 4, 3, 3, 2, 2,
# ...

# %%
model1.score(x_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_absolute_error 
import sklearn as sk 
sk.metrics.mean_squared_error(y_test,y_pred)
# Out:
# 0.018

# %%
mae =mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 0.018

# %%
import numpy as np

# %%
np.sqrt(mae)
# Out:
# np.float64(0.1341640786499874)

# %%
from sklearn.metrics import accuracy_score 
acc=accuracy_score(y_test,y_pred)*100 
print("Accuracy of Gaussian Naive-Bayes model:",acc,"%")
# Out:
# Accuracy of Gaussian Naive-Bayes model: 98.2 %

# %%
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[299,   7,   0,   0],
#        [  4, 352,   1,   0],
#        [  0,   0, 208,   2],
#        [  0,   0,   4, 123]])

# %%
classes, counts = np.unique(y_pred, return_counts=True)

# Create Pie Chart
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=classes, autopct="%1.1f%%", colors=['blue', 'green', 'orange', 'red'])
plt.title("Naïve Bayes Prediction Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 1", "Class 2", "Class 3", "Class 4"], yticklabels=["Class 1", "Class 2", "Class 3", "Class 4"])
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.title("Confusion Matrix for Logistic Regression")
plt.show()

# %%
from sklearn.metrics import precision_score 
pr=precision_score(y_test,y_pred,average='macro')

# %%
pr
# Out:
# 0.9819564735554728

# %%
from sklearn.metrics import recall_score 
re=recall_score(y_test,y_pred,average='macro')

# %%
re
# Out:
# 0.9805246770624261

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_pred, average="macro")

# %%
f1
# Out:
# 0.9812049597311118

# %%
from sklearn.metrics import classification_report 
cr=classification_report(y_test,y_pred)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.99      0.98      0.98       306
#            2       0.98      0.99      0.98       357
#            3       0.98      0.99      0.98       210
#            4       0.98      0.97      0.98       127
#
#     accuracy                           0.98      1000
#    macro avg       0.98      0.98      0.98      1000
# weighted avg       0.98      0.98      0.98      1000

# %% [markdown]
# Model No.3
#
# Multinomial Naive-Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
model2=MultinomialNB()

# %%
model2
# Out:
# MultinomialNB()

# %%
model2.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=model2.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 2, 4, 3, 1, 3, 1, 1, 1, 2, 4, 1, 1, 4, 1, 1,
#        3, 1, 1, 3, 1, 4, 2, 4, 3, 4, 3, 1, 2, 2, 3, 4, 2, 4, 1, 4, 1, 4,
#        3, 2, 1, 3, 2, 2, 2, 3, 3, 4, 1, 3, 3, 2, 2, 2, 2, 1, 4, 2, 3, 2,
#        3, 1, 3, 2, 4, 4, 2, 2, 2, 2, 3, 3, 2, 2, 2, 2, 1, 1, 4, 1, 2, 1,
#        1, 4, 4, 1, 2, 3, 2, 4, 2, 4, 3, 4, 2, 2, 3, 4, 1, 1, 3, 3, 2, 4,
#        2, 2, 4, 2, 1, 2, 2, 1, 2, 1, 1, 2, 2, 4, 2, 1, 3, 3, 2, 2, 1, 3,
#        4, 1, 3, 3, 2, 1, 2, 3, 2, 3, 2, 2, 2, 2, 3, 4, 2, 2, 2, 3, 1, 2,
#        4, 1, 1, 2, 2, 2, 2, 2, 2, 4, 1, 3, 4, 2, 4, 4, 2, 1, 2, 4, 4, 2,
#        1, 2, 1, 2, 3, 2, 2, 2, 3, 2, 1, 2, 2, 3, 1, 3, 2, 3, 2, 2, 1, 2,
#        2, 2, 3, 1, 1, 2, 2, 1, 1, 2, 3, 1, 2, 4, 2, 2, 2, 3, 1, 3, 1, 2,
#        1, 2, 4, 2, 4, 3, 1, 4, 1, 2, 1, 2, 2, 2, 2, 2, 1, 2, 1, 2, 2, 4,
#        1, 1, 4, 3, 2, 3, 2, 4, 4, 2, 3, 1, 1, 4, 1, 2, 3, 1, 2, 4, 1, 4,
#        1, 3, 3, 1, 1, 4, 1, 2, 1, 2, 3, 1, 4, 2, 4, 4, 1, 4, 3, 3, 2, 2,
# ...

# %%
model.score(x_test,y_pred)
# Out:
# 0.831

# %%
from sklearn.metrics import mean_absolute_error 
import sklearn as sk 
sk.metrics.mean_squared_error(y_test,y_pred)
# Out:
# 0.219

# %%
mae =mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 0.215

# %%
np.sqrt(mae)
# Out:
# np.float64(0.4636809247747852)

# %%
from sklearn.metrics import accuracy_score 
acc=accuracy_score(y_test,y_pred)*100 
print("Accuracy of Multinomial model:",acc,"%")
# Out:
# Accuracy of Multinomial model: 78.7 %

# %%
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[267,  39,   0,   0],
#        [ 15, 297,  43,   2],
#        [  0,  16, 142,  52],
#        [  0,   0,  46,  81]])

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Reds")
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.title("Confusion Matrix - Multinomial Naïve Bayes")
plt.show()

# %%
from sklearn.metrics import precision_score 
pr=precision_score(y_test,y_pred,average='macro')

# %%
pr
# Out:
# 0.7513192813392281

# %%
from sklearn.metrics import recall_score 
re=recall_score(y_test,y_pred,average='macro')

# %%
re
# Out:
# 0.7546168861245286

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_pred, average="macro")

# %%
f1
# Out:
# 0.7520686309027285

# %%
from sklearn.metrics import classification_report 
cr=classification_report(y_test,y_pred)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.95      0.87      0.91       306
#            2       0.84      0.83      0.84       357
#            3       0.61      0.68      0.64       210
#            4       0.60      0.64      0.62       127
#
#     accuracy                           0.79      1000
#    macro avg       0.75      0.75      0.75      1000
# weighted avg       0.80      0.79      0.79      1000

# %% [markdown]
# Model No.4
#
# Decision-Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model3=DecisionTreeClassifier()

# %%
model3
# Out:
# DecisionTreeClassifier()

# %%
model3.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 2, 4, 3, 2, 4, 1, 1, 1, 2, 4, 1, 1, 4, 1, 1,
#        3, 1, 1, 4, 1, 3, 2, 3, 3, 4, 3, 1, 2, 1, 3, 4, 2, 4, 1, 4, 1, 4,
#        3, 2, 1, 3, 2, 2, 2, 3, 2, 4, 1, 3, 3, 2, 2, 2, 2, 1, 3, 2, 2, 1,
#        3, 1, 4, 2, 4, 4, 2, 2, 2, 1, 3, 3, 2, 2, 2, 2, 1, 1, 4, 1, 2, 1,
#        2, 3, 4, 1, 2, 2, 2, 4, 2, 4, 4, 4, 2, 2, 3, 4, 1, 1, 2, 2, 2, 4,
#        1, 2, 4, 2, 1, 2, 2, 1, 1, 1, 1, 2, 2, 4, 2, 1, 3, 2, 2, 2, 1, 3,
#        4, 1, 3, 2, 3, 1, 2, 3, 2, 3, 2, 2, 2, 2, 3, 3, 2, 2, 2, 4, 1, 2,
#        4, 1, 1, 2, 2, 2, 2, 2, 2, 3, 2, 3, 3, 2, 4, 4, 2, 1, 2, 4, 4, 2,
#        1, 2, 1, 2, 3, 2, 2, 2, 3, 2, 1, 2, 2, 3, 1, 3, 2, 2, 2, 2, 1, 2,
#        1, 2, 3, 1, 1, 2, 2, 1, 1, 2, 3, 1, 2, 4, 2, 2, 2, 4, 1, 3, 1, 2,
#        1, 2, 4, 2, 4, 2, 1, 4, 1, 2, 1, 2, 2, 2, 2, 1, 1, 2, 1, 1, 2, 4,
#        1, 1, 4, 3, 2, 3, 1, 4, 4, 2, 3, 1, 1, 3, 1, 2, 3, 1, 2, 4, 1, 3,
#        1, 3, 2, 1, 1, 4, 1, 2, 1, 2, 4, 1, 4, 2, 4, 4, 1, 4, 3, 3, 2, 2,
# ...

# %%
model.score(x_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_absolute_error 
import sklearn as sk 
sk.metrics.mean_squared_error(y_test,y_pred)
# Out:
# 0.149

# %%
mae = mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 0.149

# %%
np.sqrt(mae)
# Out:
# np.float64(0.38600518131237566)

# %%
from sklearn.metrics import accuracy_score 
acc=accuracy_score(y_test,y_pred)*100 
print("Accuracy of Decision-tree model:",acc,"%")
# Out:
# Accuracy of Decision-tree model: 85.1 %

# %%
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[286,  20,   0,   0],
#        [ 15, 325,  17,   0],
#        [  0,  25, 142,  43],
#        [  0,   0,  29,  98]])

# %%
importance = model3.feature_importances_
print(importance)
plt.barh(x_train.columns, importance, color="blue")
plt.xlabel("Features")
plt.ylabel("Importance")
plt.title("Decision Tree - Feature Importance")
plt.show()
# Out:
# [0.00253716 0.9695274  0.00640294 0.00149698 0.00134431 0.00352757
#  0.0017658  0.00482414 0.00275561 0.00581809]

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 6))

plot_tree(model3, filled=True)
plt.show()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(30,20), dpi=100)  
plot_tree(model3, rounded=True, fontsize=12)
plt.show()

# %%
from sklearn.metrics import precision_score 
pr=precision_score(y_test,y_pred,average='macro')

# %%
pr
# Out:
# 0.8197247753160667

# %%
from sklearn.metrics import recall_score 
re=recall_score(y_test,y_pred,average='macro')

# %%
re
# Out:
# 0.8232121720079107

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_pred, average="macro")

# %%
f1
# Out:
# 0.8203339446822896

# %%
from sklearn.metrics import classification_report 
cr=classification_report(y_test,y_pred)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.95      0.93      0.94       306
#            2       0.88      0.91      0.89       357
#            3       0.76      0.68      0.71       210
#            4       0.70      0.77      0.73       127
#
#     accuracy                           0.85      1000
#    macro avg       0.82      0.82      0.82      1000
# weighted avg       0.85      0.85      0.85      1000

# %% [markdown]
# Model No.5
#
# Linear SVM

# %%
from sklearn.svm import SVC
model4 = SVC(kernel='rbf')

# %%
model4
# Out:
# SVC()

# %%
model4.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred = model4.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 2, 3, 4, 1, 4, 1, 1, 1, 2, 3, 1, 1, 4, 1, 1,
#        3, 2, 1, 3, 1, 3, 2, 2, 3, 4, 2, 1, 1, 1, 3, 4, 2, 4, 1, 4, 1, 3,
#        3, 2, 1, 3, 2, 2, 3, 3, 3, 4, 1, 3, 3, 2, 2, 2, 2, 1, 4, 2, 2, 1,
#        3, 1, 4, 2, 4, 4, 2, 2, 3, 1, 3, 3, 2, 2, 2, 2, 1, 1, 4, 1, 2, 1,
#        1, 3, 4, 1, 2, 3, 2, 4, 2, 4, 3, 4, 2, 2, 3, 4, 1, 1, 2, 2, 2, 3,
#        1, 2, 3, 2, 1, 3, 2, 1, 1, 1, 1, 2, 2, 4, 2, 1, 3, 2, 2, 2, 1, 3,
#        3, 1, 3, 3, 3, 1, 2, 3, 2, 2, 2, 2, 2, 2, 3, 4, 2, 2, 2, 4, 1, 2,
#        3, 1, 1, 1, 2, 2, 2, 2, 2, 3, 2, 3, 4, 2, 4, 4, 2, 1, 2, 4, 3, 2,
#        1, 2, 1, 2, 3, 2, 2, 2, 4, 2, 2, 2, 1, 3, 1, 3, 2, 2, 2, 2, 1, 2,
#        1, 2, 3, 1, 1, 2, 1, 1, 1, 2, 4, 1, 2, 4, 2, 3, 2, 4, 1, 3, 1, 2,
#        1, 2, 4, 2, 3, 2, 1, 4, 1, 3, 1, 2, 1, 3, 2, 1, 1, 2, 1, 1, 2, 4,
#        1, 1, 4, 3, 2, 3, 1, 4, 4, 2, 3, 1, 1, 3, 1, 2, 3, 1, 2, 4, 1, 4,
#        1, 3, 2, 1, 1, 4, 1, 2, 1, 2, 4, 1, 4, 2, 4, 4, 1, 4, 3, 3, 2, 2,
# ...

# %%
model4.score(x_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_absolute_error 
import sklearn as sk 
sk.metrics.mean_squared_error(y_test,y_pred)
# Out:
# 0.02

# %%
mae =mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 0.02

# %%
np.sqrt(mae)
# Out:
# np.float64(0.1414213562373095)

# %%
from sklearn.metrics import accuracy_score 
acc=accuracy_score(y_test,y_pred)*100 
print("Accuracy of Linear-SVM model:",acc,"%")
# Out:
# Accuracy of Linear-SVM model: 98.0 %

# %%
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[303,   3,   0,   0],
#        [  4, 351,   2,   0],
#        [  0,   0, 204,   6],
#        [  0,   0,   5, 122]])

# %%
correct= sum(y_test == y_pred)
incorrect = len(y_test) - correct  

labels = ['Correct', 'Incorrect']
sizes = [correct, incorrect]
colors = ['lightgreen', 'salmon']

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('SVM Prediction Results')
plt.show()

# %%
from sklearn.metrics import precision_score 
pr=precision_score(y_test,y_pred,average='macro')

# %%
pr
# Out:
# 0.9746114380794162

# %%
from sklearn.metrics import recall_score 
re=recall_score(y_test,y_pred,average='macro')

# %%
re
# Out:
# 0.9763619621076778

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_pred, average="macro")

# %%
f1
# Out:
# 0.9754766019500716

# %%
from sklearn.metrics import classification_report 
cr=classification_report(y_test,y_pred)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99       306
#            2       0.99      0.98      0.99       357
#            3       0.97      0.97      0.97       210
#            4       0.95      0.96      0.96       127
#
#     accuracy                           0.98      1000
#    macro avg       0.97      0.98      0.98      1000
# weighted avg       0.98      0.98      0.98      1000

# %% [markdown]
# Model No.6
#
# Non-linear SVM

# %%
from sklearn.svm import SVC
model5 = SVC(kernel='poly')

# %%
model5
# Out:
# SVC(kernel='poly')

# %%
model5.fit(x_train, y_train)
# Out:
# SVC(kernel='poly')

# %%
y_pred =model5.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 2, 3, 4, 1, 4, 1, 1, 1, 2, 3, 1, 1, 4, 1, 1,
#        3, 2, 1, 3, 1, 3, 2, 2, 3, 4, 2, 1, 1, 1, 3, 4, 2, 4, 1, 4, 1, 3,
#        3, 2, 1, 3, 2, 2, 3, 3, 3, 4, 1, 3, 3, 2, 2, 2, 2, 1, 4, 2, 2, 1,
#        3, 1, 4, 2, 4, 4, 2, 2, 3, 1, 3, 3, 2, 2, 2, 2, 1, 1, 4, 1, 2, 1,
#        1, 3, 4, 1, 2, 3, 2, 4, 2, 4, 3, 4, 2, 2, 3, 4, 1, 1, 2, 2, 2, 3,
#        1, 2, 3, 2, 1, 3, 2, 1, 1, 1, 1, 2, 2, 4, 2, 1, 3, 2, 2, 2, 1, 3,
#        3, 1, 3, 3, 3, 1, 2, 3, 2, 2, 2, 2, 2, 2, 3, 4, 2, 2, 2, 4, 1, 2,
#        3, 1, 1, 1, 2, 2, 2, 2, 2, 3, 2, 3, 4, 2, 4, 4, 2, 1, 2, 4, 3, 2,
#        1, 2, 1, 2, 3, 2, 2, 2, 4, 2, 2, 2, 1, 3, 1, 2, 2, 2, 2, 2, 1, 2,
#        2, 2, 3, 1, 1, 2, 1, 1, 1, 2, 4, 1, 2, 4, 2, 3, 2, 4, 1, 3, 1, 2,
#        1, 2, 4, 2, 3, 2, 1, 4, 1, 3, 1, 2, 1, 3, 2, 1, 1, 2, 1, 1, 2, 4,
#        1, 1, 4, 3, 2, 3, 1, 4, 4, 2, 3, 1, 1, 3, 1, 2, 4, 1, 2, 4, 1, 4,
#        1, 3, 2, 1, 1, 4, 1, 2, 1, 2, 4, 1, 4, 2, 4, 4, 1, 4, 3, 3, 2, 2,
# ...

# %%
model4.score(x_test,y_pred)
# Out:
# 0.993

# %%
from sklearn.metrics import mean_absolute_error 
import sklearn as sk 
sk.metrics.mean_squared_error(y_test,y_pred)
# Out:
# 0.021

# %%
mae =mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 0.021

# %%
np.sqrt(mae)
# Out:
# np.float64(0.14491376746189438)

# %%
from sklearn.metrics import accuracy_score 
acc=accuracy_score(y_test,y_pred)*100 
print("Accuracy of Non-Linear-SVM model:",acc,"%")
# Out:
# Accuracy of Non-Linear-SVM model: 97.89999999999999 %

# %%
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[303,   3,   0,   0],
#        [  4, 350,   3,   0],
#        [  0,   1, 203,   6],
#        [  0,   0,   4, 123]])

# %%
counts = [sum(y_pred == i) for i in [1, 2, 3, 4]]
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=['1', '2', '3', '4'], autopct='%1.1f%%')
plt.title('SVM(Non-Linear) Prediction for each Categories')
plt.show()

# %%
from sklearn.metrics import precision_score 
pr=precision_score(y_test,y_pred,average='macro')

# %%
pr
# Out:
# 0.9739565719426323

# %%
from sklearn.metrics import recall_score 
re=recall_score(y_test,y_pred,average='macro')

# %%
re
# Out:
# 0.9764397097421647

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_pred, average="macro")

# %%
f1
# Out:
# 0.9751784374261488

# %%
from sklearn.metrics import classification_report 
cr=classification_report(y_test,y_pred)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99       306
#            2       0.99      0.98      0.98       357
#            3       0.97      0.97      0.97       210
#            4       0.95      0.97      0.96       127
#
#     accuracy                           0.98      1000
#    macro avg       0.97      0.98      0.98      1000
# weighted avg       0.98      0.98      0.98      1000

# %% [markdown]
# ACCURACY COMPARISON

# %%
models = ["Logistic Regression", "Gaussian NB", "Multinomial NB", 
          "Decision Tree", "Linear SVM", "Non-Linear SVM"]
accuracies = [85.1, 98.2, 78.7, 85.1, 98.0, 97.89]

for i, v in enumerate(accuracies):
    plt.text(i, v + 0.5, str(v), ha='center', fontsize=10)
    
plt.bar(models, accuracies, color="red")
plt.xticks(rotation=20)  
plt.xlabel("Models")
plt.ylabel("Accuracy (%)")
plt.title("Model Accuracy Comparison")

plt.show()
